# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **John Bellas**

# %% [markdown]
# Account Executive

# %% [markdown]
# _I am interested in Data Science so that I can better understand the tools and methodolgy used by Data Scientists_

# %% [markdown]
# ### Below I have a line of code that solves the equation  1+10/5*6

# %%
1+10/5*6
# Out:
# 13.0

# %% [markdown]
# ~~Striketrhough this line of text~~

# %% [markdown]
# > This is a blockquote

# %% [markdown]
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
